# %%
import yfinance as yf
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Load Tesla data
tesla = yf.Ticker("TSLA")

# Fetch historical data for the last year
tesla_data = tesla.history(period="1y")

# Display the first few rows of the data
tesla_data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-11-27 00:00:00-05:00  236.889999  238.330002  232.100006  236.080002
# 2023-11-28 00:00:00-05:00  236.679993  247.000000  234.009995  246.720001
# 2023-11-29 00:00:00-05:00  249.210007  252.750000  242.759995  244.139999
# 2023-11-30 00:00:00-05:00  245.139999  245.220001  236.910004  240.080002
# 2023-12-01 00:00:00-05:00  233.139999  240.190002  231.899994  238.830002
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-11-27 00:00:00-05:00  112031800        0.0           0.0
# 2023-11-28 00:00:00-05:00  148549900        0.0           0.0
# 2023-11-29 00:00:00-05:00  135401300        0.0           0.0
# 2023-11-30 00:00:00-05:00  132353200        0.0           0.0
# 2023-12-01 00:00:00-05:00  121173500        0.0           0.0

# %%
tesla_data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-11-21 00:00:00-05:00  343.809998  347.989990  335.279999  339.640015
# 2024-11-22 00:00:00-05:00  341.089996  361.529999  337.700012  352.559998
# 2024-11-25 00:00:00-05:00  360.140015  361.929993  338.200012  338.589996
# 2024-11-26 00:00:00-05:00  341.000000  346.959991  335.660004  338.230011
# 2024-11-27 00:00:00-05:00  341.970001  342.549988  326.589996  332.140015
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-11-21 00:00:00-05:00  58011700        0.0           0.0
# 2024-11-22 00:00:00-05:00  89140700        0.0           0.0
# 2024-11-25 00:00:00-05:00  95890900        0.0           0.0
# 2024-11-26 00:00:00-05:00  62089200        0.0           0.0
# 2024-11-27 00:00:00-05:00  40738375        0.0           0.0

# %%
tesla_data.index
# Out:
# DatetimeIndex(['2023-11-27 00:00:00-05:00', '2023-11-28 00:00:00-05:00',
#                '2023-11-29 00:00:00-05:00', '2023-11-30 00:00:00-05:00',
#                '2023-12-01 00:00:00-05:00', '2023-12-04 00:00:00-05:00',
#                '2023-12-05 00:00:00-05:00', '2023-12-06 00:00:00-05:00',
#                '2023-12-07 00:00:00-05:00', '2023-12-08 00:00:00-05:00',
#                ...
#                '2024-11-14 00:00:00-05:00', '2024-11-15 00:00:00-05:00',
#                '2024-11-18 00:00:00-05:00', '2024-11-19 00:00:00-05:00',
#                '2024-11-20 00:00:00-05:00', '2024-11-21 00:00:00-05:00',
#                '2024-11-22 00:00:00-05:00', '2024-11-25 00:00:00-05:00',
#                '2024-11-26 00:00:00-05:00', '2024-11-27 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=254, freq=None)

# %%
tesla_data['Open'].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
tesla_data['High'].plot(xlim=['2023-11-27','2024-05-10'],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data['High'].plot(xlim=['2023-11-27','2024-05-10'],ylim=[150,300],figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data['Open'].plot(xlim=['2023-11-27','2024-05-10'],ylim=[120,280],figsize=(15,6),ls="--",color='g')
# Out:
# <Axes: xlabel='Date'>

# %%
tesla_data['Open'].plot(xlim=['2023-11-27','2024-05-10'],ylim=[120,280],figsize=(15,6),color='g')
tesla_data['Close'].plot(xlim=['2023-11-27','2024-05-10'],ylim=[120,280],figsize=(15,6),color='k')
tesla_data['High'].plot(xlim=['2023-11-27','2024-05-10'],ylim=[120,280],figsize=(15,6),lw=2,color='r')
plt.legend()

# %%
tesla_data['Open'].plot(figsize=(15,6),color='g')
tesla_data['Close'].plot(figsize=(15,6),color='k')
plt.legend()

# %%
tesla_data['Open'].plot(figsize=(15,6),color='g',label='Actual opening')
tesla_data['Open'].rolling(window=5,min_periods=1).mean().plot(figsize=(15,6),color='k',label='SMA')
plt.title("Actual opening with Simple moving average")
plt.legend()

# %%
(236.889999 + 236.679993 + 249.210007 + 245.139999 + 233.139999)/ 5
# Out:
# 240.21199939999997
