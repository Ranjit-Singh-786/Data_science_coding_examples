# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import re ###regular expression

# %%
####file handling ###
import os

# %%
file = open('demo.txt','w')

# %%
message = """hi we are from upflair
 and thank you for joining""" 
file =open('demo.txt','w')
file.write(message)
file.close()

# %%
file = open('demo.txt','r')
data =file.read()
print(data)
# Out:
# hi we are from upflair
#  and thank you for joining

# %%
message = """\nhi we are from upflair
 and thank you for joining""" 
file =open('demo.txt','a')
file.write(message)
file.close()
##\n is new line character

# %%
file = open('demo.txt','r')
data =file.read()
print(data)
# Out:
# hi we are from upflair
#  and thank you for joining
# hi we are from upflair
#  and thank you for joining

# %%
file = open('demo.txt','r')
data =file.read()
file.close() #to close the file in the folder
print(data)
# Out:
# hi we are from upflair
#  and thank you for joining
# hi we are from upflair
#  and thank you for joining

# %%
with open('demo.txt','r') as file:
    data= file.read()
    print(data)
    #your file will close automatically with 'with' function in indentation
# Out:
# hi we are from upflair
#  and thank you for joining
# hi we are from upflair
#  and thank you for joining

# %%
import os
print(os.getcwd())

file_path ="./Data/SMSSpamCollection.txt"
# Out:
# c:\Users\punit\language\python\machine learning\email_classification

# %%
with open('./Data/SMSSpamCollection.txt','r') as file:
    data= file.read()
    print(data)
# Out:
# ham	Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# ham	Ok lar... Joking wif u oni...
# spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# ham	U dun say so early hor... U c already then say...
# ham	Nah I don't think he goes to usf, he lives around here though
# spam	FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, Â£1.50 to rcv
# ham	Even my brother is not like to speak with me. They treat me like aids patent.
# ham	As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# ...

# %%
for i in range (100):
    message = """\nhi we are from upflair
    and thank you for joining""" 
    file =open('assign.txt','a')
    file.write(message)
    file.close()

# %%
file_path = './Data/SMSSpamCollection.txt'
file =open(file_path)
data =file.read()
file.close()

# %%
print("total no of emails :",len(data.split('\n')))
# Out:
# total no of emails : 5575

# %%
data.split('\n') # to split every line content
# Out:
# ['ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  'ham\tOk lar... Joking wif u oni...',
#  "spam\tFree entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#  'ham\tU dun say so early hor... U c already then say...',
#  "ham\tNah I don't think he goes to usf, he lives around here though",
#  "spam\tFreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, Â£1.50 to rcv",
#  'ham\tEven my brother is not like to speak with me. They treat me like aids patent.',
#  "ham\tAs per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
# ...

# %%
print('totla no of emails',len(data.split('\n')))
# Out:
# totla no of emails 5575

# %%
data.split('\n')[1]
# Out:
# 'ham\tOk lar... Joking wif u oni...'

# %%
x=[]
y=[]
for line in data.split('\n'):
    if len(line.split('\t'))==2:
        y.append(line.split('\t')[0])
        x.append(line.split('\t')[1])

# %%
len(x),len(y)
# Out:
# (5574, 5574)

# %%
x[1]
# Out:
# 'Ok lar... Joking wif u oni...'

# %%
y[1]
# Out:
# 'ham'

# %%
#create dataframe
email_data=pd.DataFrame({"email_messages":x,"labels":y})
email_data.head()
# Out:
#                                       email_messages labels
# 0  Go until jurong point, crazy.. Available only ...    ham
# 1                      Ok lar... Joking wif u oni...    ham
# 2  Free entry in 2 a wkly comp to win FA Cup fina...   spam
# 3  U dun say so early hor... U c already then say...    ham
# 4  Nah I don't think he goes to usf, he lives aro...    ham

# %%
df2=pd.read_table(file_path)
df2.columns=["labels","email_messages"]

# %%
df2.head()
# Out:
#   labels                                     email_messages
# 0    ham                      Ok lar... Joking wif u oni...
# 1   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2    ham  U dun say so early hor... U c already then say...
# 3    ham  Nah I don't think he goes to usf, he lives aro...
# 4   spam  FreeMsg Hey there darling it's been 3 week's n...

# %%
##data collection ,gathering
##data manipulation
##data wrangling
#data cleaning
## data pre-processing
#data preparation
## data visualization 
# data normalization or scaling 
## feature engineering 
# feature extraction 
### data transformation
#feature selection
### machine learning life cycle
## laptop price predction

# %%
print('total no of email',df2.shape[0])
# Out:
# total no of email 5571

# %%
single_email=df2['email_messages'][1]
single_email
# Out:
# "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"

# %%
type(single_email)
# Out:
# str

# %%
single_email=single_email.lower()

# %%
single_email
# Out:
# "free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005. text fa to 87121 to receive entry question(std txt rate)t&c's apply 08452810075over18's"

# %%
re.findall('2',single_email)
# Out:
# ['2', '2', '2', '2', '2']

# %%
single_email.replace('2','H')
# Out:
# "free entry in H a wkly comp to win fa cup final tkts H1st may H005. text fa to 871H1 to receive entry question(std txt rate)t&c's apply 0845H810075over18's"

# %%
re.sub("[^a-zA-Z ]","",single_email) #substitute ^ this is for numbers
# Out:
# 'free entry in  a wkly comp to win fa cup final tkts st may  text fa to  to receive entry questionstd txt ratetcs apply overs'

# %%
re.sub("[a-zA-Z ]","",single_email) #substitute
# Out:
# "2212005.87121()&'0845281007518'"

# %%
single_email.replace('2',"")
single_email.replace('3',"")
single_email.replace('4',"")
# Out:
# "free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005. text fa to 87121 to receive entry question(std txt rate)t&c's apply 0852810075over18's"

# %%
df2
# Out:
#      labels                                     email_messages
# 0       ham                      Ok lar... Joking wif u oni...
# 1      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2       ham  U dun say so early hor... U c already then say...
# 3       ham  Nah I don't think he goes to usf, he lives aro...
# 4      spam  FreeMsg Hey there darling it's been 3 week's n...
# ...     ...                                                ...
# 5566   spam  This is the 2nd time we have tried 2 contact u...
# 5567    ham               Will ü b going to esplanade fr home?
# 5568    ham  Pity, * was in mood for that. So...any other s...
# 5569    ham  The guy did some bitching but I acted like i'd...
# 5570    ham                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]

# %%
for i in range(len(df2['email_messages'])):
    email_messages=df2['email_messages'][i]
    email_messages=email_messages.lower()
    df2['email_messages'][i]=re.sub("[^a-zA-Z ]","",email_messages)
# Out:
# C:\Users\punit\AppData\Local\Temp\ipykernel_6816\3481566189.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df2['email_messages'][i]=re.sub("[^a-zA-Z ]","",email_messages)

# %%
df2['labels'].value_counts()
# Out:
# labels
# ham     4824
# spam     747
# Name: count, dtype: int64

# %%
###what is smote

# %%
#divide data into ham and email

# %%
ham=df2[df2['labels']=="ham"]
spam=df2[df2['labels']=='spam']

# %%
ham=ham.sample(1000)

# %%
ham.shape
# Out:
# (1000, 2)

# %%
ham.sample()
# Out:
#      labels                                     email_messages
# 4251    ham  omg joanna is freaking me out shes looked thru...

# %%
spam=spam.sample(1000,replace=True).shape  #it copy paste same points

# %%
spam.shape,ham.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 spam.shape ,ham.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
new_df=pd.concat([spam,ham])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 new_df=pd.concat([spam,ham])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
new_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 new_df.shape
#
# NameError: name 'new_df' is not defined

# %%
new_df.duplicated().sum()

# %%
spam.duplicated().sum()

# %%
ham.duplicated().sum()

# %%
new_df['labels'].value_counts()

# %%
new_df['labels'] = new_df['labels'].map({'spam':1,'ham':0})

# %%
x = new_df['email_message']
y = new_df['labels']

# %%
type(x)
# Out:
# list

# %%
x = x.values

# %%
type(x)

# %%
x.shape,len(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 x.shape,len(y)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
bow_obj = CountVectorizer(max_features=1500,stop_words='english')

X = bow_obj.fit_transform(x)

# %%
X_transformed = X.toarray()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 bow_obj=CountVectorizer(max_df_features=1500,stop_words='english')
#       2 x=bow_obj.fit_transform(x)
#       3 x
#
# TypeError: CountVectorizer.__init__() got an unexpected keyword argument 'max_df_features'

# %%
X_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 X.toarray()
#
# NameError: name 'X' is not defined

# %%
y.shape  , X_transformed.shape

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_transformed,y,test_size=0.15,random_state=42)

# %%
## Model training  algorithm train 
from sklearn.naive_bayes import MultinomialNB, BernoulliNB , GaussianNB
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
mnb.fit(x_train,y_train) 
bnb.fit(x_train,y_train) 
print("ALgorithms trained on the data!") 

print("Multinomial Naive bayes")
print("Training score : ",mnb.score(x_train,y_train))
print("Testing score : ",  mnb.score(x_test,y_test) )
print()
print("Bernoli Naive bayes")
print("Training score : ",bnb.score(x_train,y_train))
print("Testing score : ",  bnb.score(x_test,y_test) )

# %%
### prediction 
prediction = mnb.predict(x_test)
prediction

# %%
y_test.values

# %%
evaluation_df =  pd.DataFrame({"actual_class":y_test.values,"predicted_class":prediction})
evaluation_df.head(40)

# %%
evaluation_df['actual_class'] = evaluation_df['actual_class'].map({1:'spam',0:'ham'})
evaluation_df['predicted_class'] = evaluation_df['predicted_class'].map({1:'spam',0:'ham'})

# %%
evaluation_df.head(40)

# %%
learn.metrics import confusion_matrix , classification_report

# %%
matrix = confusion_matrix(evaluation_df['actual_class'],evaluation_df['predicted_class'])
matrix

# %%
import seaborn   as sns 
import matplotlib.pyplot as plt

# %%
sns.heatmap(matrix,annot=True,fmt='d') 
plt.title('Confusion matrix')
plt.axis('off')
plt.show()

# %%
print(classification_report(evaluation_df['actual_class'],evaluation_df['predicted_class']))

# %%
## Models save  
import joblib , os 
os.makedirs('models',exist_ok=True)

joblib.dump(mnb,'./models/multinomialnaivebayes.lb')
joblib.dump(bnb,'./models/bernolinaivebayes.lb')
joblib.dump(bow_obj,'./models/countvectorizer.lb')
print("Your object is saved!")
