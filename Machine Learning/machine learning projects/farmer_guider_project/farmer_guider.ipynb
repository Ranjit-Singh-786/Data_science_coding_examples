# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/JECRC-20april2024/main/farmer.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.to_csv('farmer.csv',index=False)

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
#supervised learning = classification,regression
#unsupervised learning = clustering
#unsupervised learning group data based on the similarity

# %%
group = df.groupby('label')

# %%
group[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
group[['N']].mean()
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
df['label'].nunique()
# Out:
# 22

# %%
df['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
nitrogen = group['N'].agg(min_nitro='min',max_nitro='max',avg_nitro='mean')
nitrogen
# Out:
#              min_nitro  max_nitro  avg_nitro
# label
# apple                0         40      20.80
# banana              80        120     100.23
# blackgram           20         60      40.02
# chickpea            20         60      40.09
# coconut              0         40      21.98
# coffee              80        120     101.20
# cotton             100        140     117.77
# grapes               0         40      23.18
# jute                60        100      78.40
# kidneybeans          0         40      20.75
# lentil               0         40      18.77
# maize               60        100      77.76
# mango                0         40      20.07
# mothbeans            0         40      21.44
# mungbean             0         40      20.99
# muskmelon           80        120     100.32
# orange               0         40      19.58
# papaya              31         70      49.88
# pigeonpeas           0         40      20.73
# pomegranate          0         40      18.87
# rice                60         99      79.89
# watermelon          80        120      99.42

# %%
nitrogen.index
# Out:
# Index(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango',
#        'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas',
#        'pomegranate', 'rice', 'watermelon'],
#       dtype='object', name='label')

# %%
nitrogen.reset_index(inplace=True)

# %%
# sns.set(rc={'figure.figsize:'(8,18)})
sns.catplot(x ='label',y='avg_nitro',data=nitrogen,kind='bar',ec ='k',color='g')
plt.xticks(rotation=270)
plt.show()

# %%
sns.catplot(x ='label',y='max_nitro',data=nitrogen,kind='bar',ec ='k',color='g')
plt.xticks(rotation=270)
plt.show()

# %%
sns.catplot(x ='label',y='min_nitro',data=nitrogen,kind='bar',ec ='k',color='g')
plt.xticks(rotation=270)
plt.show()

# %%
crops_label=list(nitrogen['label'])
avg_nitrogen=list(nitrogen['avg_nitro'])
plt.pie(avg_nitrogen,labels=crops_label,autopct='%2.2f%%')
plt.show()

# %%
crops_label=list(nitrogen['label'])
avg_nitrogen=list(nitrogen['max_nitro'])
plt.pie(avg_nitrogen,labels=crops_label,autopct='%2.2f%%')
plt.show()

# %%
crops_label=list(nitrogen['label'])
avg_nitrogen=list(nitrogen['min_nitro'])
plt.pie(avg_nitrogen,labels=crops_label,autopct='%2.2f%%',wedgeprops={'ec':'k'})
plt.show()

# %%
temp =group['temperature'].agg(avg_temp='mean',min_temp='min',max_temp='max')

# %%
## unsupervised  X 
x = df.drop('label',axis=1)
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.boxplot(df['P'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1eb08830560>,
#   <matplotlib.lines.Line2D at 0x1eb089446b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1eb089449b0>,
#   <matplotlib.lines.Line2D at 0x1eb08944bf0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1eb08944260>],
#  'medians': [<matplotlib.lines.Line2D at 0x1eb08944e60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1eb089450d0>],
#  'means': []}

# %%
i = 1 
for col in x.columns: 
    plt.subplot(3,3,i)
    plt.title(col)
    plt.boxplot(df[col])
    i += 1

# %%
plt.subplot(2,2,1)
plt.boxplot(df['P'])
plt.show()

plt.subplot(2,2,2)
plt.boxplot(df['N'])
plt.show()

plt.subplot(2,2,3)
plt.boxplot(df['K'])
plt.show()

# %%
#kmeans for better accuracy you have to pass normalized data
from sklearn.preprocessing import MinMaxScaler , RobustScaler ,Normalizer , StandardScaler 
std = StandardScaler()

# %%
df['N'].mean()
# Out:
# 50.551818181818184

# %%
x_transformed =  std.fit_transform(x)

# %%
x_transformed
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
x.shape
# Out:
# (2200, 7)

# %%
#  euclidian distance method

# %%
from sklearn.cluster import KMeans  
kmeans = KMeans()  
kmeans.fit(x_transformed)
# Out:
# KMeans()

# %%
np.unique(kmeans.labels_)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
kmeans.labels_.shape  , df.shape
# Out:
# ((2200,), (2200, 8))

# %%
df['cluster_no'] = kmeans.labels_

# %%
groupno_six = df[df['cluster_no'] == 5 ]

# %%
groupno_six['label'].unique()
# Out:
# array(['pigeonpeas', 'mothbeans', 'lentil', 'mango'], dtype=object)

# %%
# saving the objects 
import os,joblib 
os.makedirs('models',exist_ok=True) 

joblib.dump(kmeans,'./models/kmeans_model.lb')
joblib.dump(std,'./models/standardscaler.lb') 
print('Your model has been saved!')
# Out:
# Your model has been saved!

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(x_transformed,kmeans.labels_)
# Out:
# 0.3265725788326684

# %%
df[['label','cluster_no']].to_csv('./models/filtering_data.csv',index=False)
