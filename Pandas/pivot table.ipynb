# %%
import numpy as np
import pandas as pd
import numpy.random as rd

# %%
dataa=pd.read_csv('datetimeseries.csv')
dataa.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
dataa.Date.value_counts()
# Out:
# 2019-01-24 06-AM    1
# 2019-01-07 09-AM    1
# 2019-10-15 09-AM    1
# 2017-10-14 01-AM    1
# 2019-09-11 11-AM    1
#                    ..
# 2018-08-13 03-AM    1
# 2018-06-11 01-PM    1
# 2018-07-08 01-AM    1
# 2018-03-28 11-PM    1
# 2018-07-07 08-AM    1
# Name: Date, Length: 23674, dtype: int64

# %%
dataa.shape
# Out:
# (23674, 7)

# %%
dataa.describe()
#symbol and date are a categorical column
# Out:
#                Open          High           Low         Close        Volume
# count  23674.000000  23674.000000  23674.000000  23674.000000  2.367400e+04
# mean     324.933372    327.317109    322.255521    324.926601  2.011035e+06
# std      236.189068    238.539115    233.365042    236.192308  3.673646e+06
# min       81.290000     82.000000     80.600000     81.290000  0.000000e+00
# 25%      171.522500    172.472500    170.500000    171.512500  3.993914e+05
# 50%      229.745000    231.725000    228.100000    229.725000  9.146454e+05
# 75%      402.797500    405.427500    400.030000    402.797500  2.098111e+06
# max     1418.610000   1419.960000   1388.990000   1418.610000  8.569790e+07

# %%
dataa['Volume'].max()
# Out:
# 85697897.38

# %%
dataa[['Date','Symbol']].dtypes
# Out:
# Date      object
# Symbol    object
# dtype: object

# %%
dataa.describe(exclude=[np.number])
# i am describing all object columns
# Out:
#                     Date  Symbol
# count              23674   23674
# unique             23674       1
# top     2018-12-19 01-AM  ETHUSD
# freq                   1   23674

# %%
len(dataa.columns)
# Out:
# 7

# %%
dataa.High.var()
# Out:
# 56900.90940069221

# %%
dataa.High.mean()
# Out:
# 327.3171086423925

# %%
dataa.High.std()
# Out:
# 238.53911503292747

# %%
dataa['High'].describe()
# Out:
# count    23674.000000
# mean       327.317109
# std        238.539115
# min         82.000000
# 25%        172.472500
# 50%        231.725000
# 75%        405.427500
# max       1419.960000
# Name: High, dtype: float64

# %% [markdown]
# ### standard divition

# %%
dataa.head(2)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09

# %%
dataa.std(numeric_only=True)
# Out:
# Open      2.361891e+02
# High      2.385391e+02
# Low       2.333650e+02
# Close     2.361923e+02
# Volume    3.673646e+06
# dtype: float64

# %% [markdown]
# ## pivot tables

# %%
dataa.pivot_table(index=['Date'],values=['High','Low','Open','Close']).head()
# Out:
#                    Close    High     Low    Open
# Date
# 2017-07-01 01-PM  268.79  274.93  265.00  274.83
# 2017-07-01 02-PM  265.74  269.90  265.00  268.79
# 2017-07-01 03-PM  272.57  272.74  265.00  265.74
# 2017-07-01 04-PM  268.00  272.57  267.60  272.57
# 2017-07-01 05-PM  263.51  268.44  262.39  268.00

# %%
dataa.pivot_table(index='Date',values=['High','Low','Open','Close'],columns='Symbol')
# Out:
#                    Close    High     Low    Open
# Symbol            ETHUSD  ETHUSD  ETHUSD  ETHUSD
# Date
# 2017-07-01 01-PM  268.79  274.93  265.00  274.83
# 2017-07-01 02-PM  265.74  269.90  265.00  268.79
# 2017-07-01 03-PM  272.57  272.74  265.00  265.74
# 2017-07-01 04-PM  268.00  272.57  267.60  272.57
# 2017-07-01 05-PM  263.51  268.44  262.39  268.00
# ...                  ...     ...     ...     ...
# 2020-03-13 09-AM  133.80  136.53  126.62  127.12
# 2020-03-13 10-AM  132.60  134.99  128.90  133.80
# 2020-03-13 11-AM  128.93  133.17  126.01  132.60
# 2020-03-13 12-AM  107.09  117.50  102.92  110.30
# 2020-03-13 12-PM  131.35  134.60  126.95  128.93
#
# [23674 rows x 4 columns]

# %%
dataa.pivot_table(index='Date',values=['High','Low','Open','Close'],columns='Symbol').isnull().sum()
# Out:
#        Symbol
# Close  ETHUSD    0
# High   ETHUSD    0
# Low    ETHUSD    0
# Open   ETHUSD    0
# dtype: int64

# %%
pvt_tble=pd.pivot_table(dataa,index=['Date'],values=['High','Low','Open','Close'])
pvt_tble.sort_index(axis='rows',ascending=False)
# Out:
#                    Close    High     Low    Open
# Date
# 2020-03-13 12-PM  131.35  134.60  126.95  128.93
# 2020-03-13 12-AM  107.09  117.50  102.92  110.30
# 2020-03-13 11-AM  128.93  133.17  126.01  132.60
# 2020-03-13 10-AM  132.60  134.99  128.90  133.80
# 2020-03-13 09-AM  133.80  136.53  126.62  127.12
# ...                  ...     ...     ...     ...
# 2017-07-01 05-PM  263.51  268.44  262.39  268.00
# 2017-07-01 04-PM  268.00  272.57  267.60  272.57
# 2017-07-01 03-PM  272.57  272.74  265.00  265.74
# 2017-07-01 02-PM  265.74  269.90  265.00  268.79
# 2017-07-01 01-PM  268.79  274.93  265.00  274.83
#
# [23674 rows x 4 columns]

# %%
pvt_tble=pd.pivot_table(dataa,index=['Date'],values=['High','Low','Open','Close'])
pvt_tble.sort_index(axis='rows')
# Out:
#                    Close    High     Low    Open
# Date
# 2017-07-01 01-PM  268.79  274.93  265.00  274.83
# 2017-07-01 02-PM  265.74  269.90  265.00  268.79
# 2017-07-01 03-PM  272.57  272.74  265.00  265.74
# 2017-07-01 04-PM  268.00  272.57  267.60  272.57
# 2017-07-01 05-PM  263.51  268.44  262.39  268.00
# ...                  ...     ...     ...     ...
# 2020-03-13 09-AM  133.80  136.53  126.62  127.12
# 2020-03-13 10-AM  132.60  134.99  128.90  133.80
# 2020-03-13 11-AM  128.93  133.17  126.01  132.60
# 2020-03-13 12-AM  107.09  117.50  102.92  110.30
# 2020-03-13 12-PM  131.35  134.60  126.95  128.93
#
# [23674 rows x 4 columns]

# %%
df=pd.read_csv('data..csv')
df.head(2)
# Out:
#    country country_code year_week     level region region_name  new_cases  \
# 0  Austria           AT  2020-W15  national     AT     Austria     1954.0
# 1  Austria           AT  2020-W16  national     AT     Austria      773.0
#
#    tests_done  population  testing_rate  positivity_rate testing_data_source
# 0       12339   8901064.0    138.623877        15.835967  Manual webscraping
# 1       58488   8901064.0    657.089984         1.321639  Manual webscraping

# %%
group=df.groupby(by='country')

# %%
group['region'].value_counts()['Austria']
# Out:
# region
# AT      68
# AT11    33
# AT12    33
# AT13    33
# AT21    33
# AT22    33
# AT31    33
# AT32    33
# AT33    33
# AT34    33
# Name: region, dtype: int64

# %%
astr=group.get_group('Austria')
astr
# Out:
#      country country_code year_week        level region region_name  \
# 0    Austria           AT  2020-W15     national     AT     Austria
# 1    Austria           AT  2020-W16     national     AT     Austria
# 2    Austria           AT  2020-W17     national     AT     Austria
# 3    Austria           AT  2020-W18     national     AT     Austria
# 4    Austria           AT  2020-W19     national     AT     Austria
# ..       ...          ...       ...          ...    ...         ...
# 360  Austria           AT  2021-W26  subnational   AT34  Vorarlberg
# 361  Austria           AT  2021-W27  subnational   AT34  Vorarlberg
# 362  Austria           AT  2021-W28  subnational   AT34  Vorarlberg
# 363  Austria           AT  2021-W29  subnational   AT34  Vorarlberg
# 364  Austria           AT  2021-W30  subnational   AT34  Vorarlberg
#
#      new_cases  tests_done  population  testing_rate  positivity_rate  \
# 0       1954.0       12339   8901064.0    138.623877        15.835967
# 1        773.0       58488   8901064.0    657.089984         1.321639
# 2        479.0       33443   8901064.0    375.719128         1.432288
# 3        349.0       26598   8901064.0    298.818209         1.312129
# 4        249.0       42153   8901064.0    473.572598         0.590705
# ..         ...         ...         ...           ...              ...
# 360       20.0      244034    394297.0  61890.909640         0.008196
# 361       25.0      236708    394297.0  60032.919350         0.010562
# 362       93.0      149065    394297.0  37805.258470         0.062389
# 363      154.0      139190    394297.0  35300.801170         0.110640
# 364      139.0      177721    394297.0  45072.876540         0.078212
#
#     testing_data_source
# 0    Manual webscraping
# 1    Manual webscraping
# 2    Manual webscraping
# 3       Country website
# 4       Country website
# ..                  ...
# 360               TESSy
# 361               TESSy
# 362               TESSy
# 363               TESSy
# 364               TESSy
#
# [365 rows x 12 columns]

# %%
australia=df[df['country']=='Austria']

# %%
df[df['country']=='Austria']['region'].value_counts()
# Out:
# AT      68
# AT13    33
# AT22    33
# AT21    33
# AT31    33
# AT12    33
# AT33    33
# AT32    33
# AT34    33
# AT11    33
# Name: region, dtype: int64

# %% [markdown]
# ### total sum of each region of Austria country

# %%
pd.pivot_table(astr,index='country',columns='region',values='new_cases',aggfunc=sum)
# Out:
# region         AT    AT11     AT12     AT13     AT21     AT22     AT31  \
# country
# Austria  627912.0  9846.0  62680.0  75576.0  23079.0  44341.0  53973.0
#
# region      AT32     AT33     AT34
# country
# Austria  27203.0  26720.0  13097.0

# %%
pd.pivot_table(df,index='country',columns='level',values='new_cases',aggfunc=sum).reset_index()
# by defult aggfunc gives mean value
# and now we will going to remove all these null value by suitable value
# and again i will create pivot_table
# Out:
# level        country   national  subnational
# 0            Austria   627912.0     336515.0
# 1            Belgium  1129525.0     459758.0
# 2           Bulgaria   422421.0          NaN
# 3            Croatia   363787.0     196827.0
# 4             Cyprus   101565.0          NaN
# 5            Czechia  1673795.0          NaN
# 6            Denmark   318485.0     274653.0
# 7            Estonia   133438.0          NaN
# 8            Finland   107321.0          NaN
# 9             France  6146607.0    3925381.0
# 10           Germany  3771980.0          NaN
# 11            Greece   494907.0     211958.0
# 12           Hungary   809646.0          NaN
# 13           Iceland     8122.0          NaN
# 14           Ireland   299103.0          NaN
# 15             Italy  4355216.0    4065922.0
# 16            Latvia   138899.0          NaN
# 17     Liechtenstein       20.0          NaN
# 18         Lithuania   282528.0     264707.0
# 19        Luxembourg    74949.0          NaN
# 20             Malta    34439.0          NaN
# 21       Netherlands  1867448.0          NaN
# 22            Norway   137950.0     129664.0
# 23            Poland  2883120.0    2869556.0
# 24          Portugal   972127.0     897410.0
# 25           Romania  1083463.0          NaN
# 26          Slovakia   773233.0          NaN
# 27          Slovenia   259486.0          NaN
# 28             Spain  4319717.0    3750233.0
# 29            Sweden  1082697.0          NaN

# %%
pd.pivot_table(df,index='country',columns='level',values='new_cases',fill_value=1)
# Out:
# level              national  subnational
# country
# Austria         9234.000000  1133.047138
# Belgium        15152.228810  5165.820225
# Bulgaria        7037.920668     1.000000
# Croatia         4604.898734  1468.858209
# Cyprus          1485.714531     1.000000
# Czechia        21187.278481     1.000000
# Denmark         4031.455696  1373.265000
# Estonia         1732.961039     1.000000
# Finland         1293.024096     1.000000
# France         81954.760000  6608.385522
# Germany        50972.702703     1.000000
# Greece          6598.760000   959.085973
# Hungary        10941.162162     1.000000
# Iceland          108.293333     1.000000
# Ireland         3834.653846     1.000000
# Italy          58069.546667  4209.028986
# Latvia          2072.408860     1.000000
# Liechtenstein     10.000000     1.000000
# Lithuania       3911.083253  3228.134146
# Luxembourg      1091.215476     1.000000
# Malta            715.785483     1.000000
# Netherlands    25581.479452     1.000000
# Norway          1839.333333   170.835310
# Poland         38961.081081  2568.984781
# Portugal       13053.588810  6798.560606
# Romania        14841.958904     1.000000
# Slovakia       10355.048765     1.000000
# Slovenia        3551.708810     1.000000
# Spain          65554.684253  4590.248470
# Sweden         15467.100000     1.000000

# %%
pd.pivot_table(df,index='country',columns='level',values='tests_done',aggfunc=sum)
# and now we will proove why becoming none value in Bulgaria and in other columns
# Out:
# level            national  subnational
# country
# Austria        86190397.0   83083691.0
# Belgium        17344776.0    9796471.0
# Bulgaria        3536697.0          NaN
# Croatia         2774639.0    1832772.0
# Cyprus          9520375.0          NaN
# Czechia        33131572.0          NaN
# Denmark        75054820.0   70142374.0
# Estonia         1522389.0          NaN
# Finland         5942482.0          NaN
# France         97959367.0   73532026.0
# Germany        67663026.0          NaN
# Greece         40865890.0   33899170.0
# Hungary         6042071.0          NaN
# Iceland          850921.0          NaN
# Ireland         5967769.0          NaN
# Italy          77397848.0   67918542.0
# Latvia          3089086.0          NaN
# Liechtenstein      2404.0          NaN
# Lithuania       4106077.0    3357053.0
# Luxembourg      4296425.0          NaN
# Malta           1016363.0          NaN
# Netherlands    21507921.0          NaN
# Norway          8454910.0    7790492.0
# Poland         19179592.0   18651843.0
# Portugal       15381817.0   12827641.0
# Romania        10069368.0          NaN
# Slovakia        6746655.0          NaN
# Slovenia        6047683.0          NaN
# Spain          50322689.0   41236959.0
# Sweden         10309313.0          NaN

# %% [markdown]
# ### why None value became prooved

# %%
print('you can see here why it become None value')
print('because it has only national level :-',df[df['country']=='Bulgaria'][['level','tests_done']]['level'].value_counts())
# Out:
# you can see here why it become None value
# because it has only national level :- national    61
# Name: level, dtype: int64
